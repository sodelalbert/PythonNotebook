# %% [markdown]
# # Markdow Syntax Exmaple
#
#
# Table of contents code example - make sure that you add HTML anchor tag `<a name>"heading"</a>` to create heading to procuce clickable references.
#
# 1. [Basic formatting](#basic)
# 2. [Hyperlinks](#links)
# 3. [Inline commamnds listings](#commands)
# 4. [Code listings](#code)
#
# ---
#
# ## Basic formatting <a name="basic"></a>
#
# `*Italic text*` - Use single asterisk character for *Italic text*
# `**Bold text**` - Use double asterisk character for **Bold text**
#
# ## Hyperlinks <a name="links"></a>
#
# ### Image embeded into Jupyter Notebook
#
# base64 image is included into raw jupyter notebook text - `ctrl + c`, `ctrl + v` is working but resizing is not possible.
# ![image.png](attachment:image.png)
#
#
#
#
# ### Position embeded images
#
#
# > How to resize and position image embeded into Jupyter Notebook?
#
# Here is the answer! Copy and paste print screen, then edit following code to match desired effect.
#
# <div>
# <img src="attachment:image.png" width="300">
# </div>
#
#
# When `width` is provided in `px` aspect ratio is keept and you no need to worry about it.
#
#
# Reference of [HTML Images](https://www.w3schools.com/html/html_images.asp) positioning.
#
#
#
# ### Inline URL example with custom name
# Example of inline URL with custom name describing above painting [Indian Summer](https://en.wikipedia.org/wiki/Indian_Summer_(painting))
#
#
#
# ## Inline commamnds listings <a name="commands"></a>
#
# To insert command example use ``` ` ``` (offically nammed "backtick") usually located betweem left shoift and `Z` on US Mac keyboard.
# To inidcate new line in Markdown add **two spaces** on the end of the line.
#
#
# `M` - Markdown
# `Y` - Code
#
#
# ## Code listings <a name="code"></a>
#
# You can create code block by adding three ``` ` ``` and specifying programming language
#
# ``` python
# def foo(a)
#     return a
#
# a = foo
# print(a(2))
#
# ```
#
#
# ## References
#
# ---
